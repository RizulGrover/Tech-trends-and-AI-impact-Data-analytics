# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..\\..")
sys.path.append(PROJECT_ROOT)

# %%
from src.engines.bigquery_engine import run_query, write_df_to_bq, run_update_query

# %%
q1=open('../sql/dashboard_6/d6_exp_v_AI.sql').read()

# %%
run_update_query(q1)
print("Dashboard 6 created successfully")
# Out:
# Dashboard 6 created successfully
